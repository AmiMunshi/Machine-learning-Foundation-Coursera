# %% [markdown]
# <a href="https://colab.research.google.com/github/AmiMunshi/Machine-learning-Foundation-Coursera/blob/main/ML_Foundations_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install turicreate
# Out:
# ...
#      |████████████████████████████████| 92.0MB 115kB/s
# ...
#      |████████████████████████████████| 327kB 40.3MB/s
# ...
#      |████████████████████████████████| 3.4MB 44.1MB/s
# ...
#      |████████████████████████████████| 86.4MB 48kB/s
# ...
#      |████████████████████████████████| 51kB 6.4MB/s
# ...
#      |████████████████████████████████| 450kB 34.0MB/s
# ...
#      |████████████████████████████████| 3.8MB 40.0MB/s
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-cp36-none-any.whl size=13700 sha256=4dac519bd1f39d16a0368e339581ea64e135fbb56441933681280a31fa2021b4
#   Stored in directory: /root/.cache/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
# ...
#   Created wheel for resampy: filename=resampy-0.2.1-cp36-none-any.whl size=320848 sha256=563ddb339265963067e086d955effe125478ce14a632e7bce2a530646d87cca5
#   Stored in directory: /root/.cache/pip/wheels/ff/4f/ed/2e6c676c23efe5394bb40ade50662e90eb46e29b48324c5f9b
# ...

# %%
import turicreate

# %%
#Load some house sales data

sales= turicreate.SFrame('/content/home_data.csv')
sales
# Out:
# Finished parsing file /content/home_data.csv
# Parsing completed. Parsed 100 lines in 0.159064 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,int,int,float,int,int,float,int,int,int,int,int,int,int,int,int,float,float,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /content/home_data.csv
# Parsing completed. Parsed 21613 lines in 0.104414 secs.
# Columns:
# 	id	int
# 	date	str
# 	price	int
# 	bedrooms	int
# 	bathrooms	float
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	int
# 	lat	float
# 	long	float
# 	sqft_living15	int
# 	sqft_lot15	int
#
# ...

# %%
#Exploring the data
sales.show()
# Out:
# Materializing SFrame
# ...

# %%
turicreate.visualization.scatter(sales['sqft_living'], sales['price'],xlabel='sqft', ylabel='price')
# Out:
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 
# ...

# %%
#create a simple regression model for sqft_lving vs price
train_data,test_data= sales.random_split(0.8, seed=0)

# %%
#Build the regression model
sqft_model=turicreate.linear_regression.create(train_data, target='price', features=['sqft_living'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %%
#Evaluate the simple model
print(test_data['price'].mean())
# Out:
# 543054.0425632533

# %%
print(sqft_model.evaluate(test_data))
# Out:
# {'max_error': 4145927.9156778366, 'rmse': 255180.73631157092}

# %%
#How our predictions look like
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(test_data['sqft_living'], test_data['price'], '*', 
         test_data['sqft_living'], sqft_model.predict(test_data), '-')

# %%
sqft_model.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+--------------------+--------------------+
# |     name    | index |       value        |       stderr       |
# +-------------+-------+--------------------+--------------------+
# | (intercept) |  None | -46222.75406213326 | 5040.910798859725  |
# | sqft_living |  None | 281.6273850742464  | 2.2192302323866535 |
# +-------------+-------+--------------------+--------------------+
# [2 rows x 4 columns]

# %%
#explore other features in the data
my_features=['bedrooms', 'bathrooms','sqft_living','sqft_lot', 'floors', 'zipcode']
sales[my_features].show()
# Out:
# Materializing SFrame
# ...

# %%
#zipcode column elements are of type int. So convert these elements to str before using it in box_plot
sales['zipcodestr']=sales['zipcode'].astype(str)

# %%
turicreate.visualization.box_plot(sales['zipcodestr'], sales['price'],xlabel='zipcode', ylabel='price')
# Out:
# <html>                 <body>                     <iframe style="border:0;margin:0" width="800" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 
# ...

# %%
#Build regression model with more feature
my_features_model= turicreate.linear_regression.create(train_data, target='price', features=my_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 7
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %%
print(sqft_model.evaluate(test_data))
print(my_features_model.evaluate(test_data))
# Out:
# {'max_error': 4145927.9156778366, 'rmse': 255180.73631157092}
# {'max_error': 3977309.726098202, 'rmse': 252862.10208038008}

# %%
sales
# Out:
# Columns:
# 	id	int
# 	date	str
# 	price	int
# 	bedrooms	int
# 	bathrooms	float
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	int
# 	lat	float
# 	long	float
# 	sqft_living15	int
# 	sqft_lot15	int
# 	zipcodestr	str
#
# Rows: 21613
#
# Data:
# +------------+-----------------+---------+----------+-----------+-------------+
# |     id     |       date      |  price  | bedrooms | bathrooms | sqft_living |
# +------------+-----------------+---------+----------+-----------+-------------+
# | 7129300520 | 20141013T000000 |  221900 |    3     |    1.0    |     1180    |
# | 6414100192 | 20141209T000000 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 20150225T000000 |  180000 |    2     |    1.0    |     770     |
# | 2487200875 | 20141209T000000 |  604000 |    4     |    3.0    |     1960    |
# ...

# %%
#Apply learned model to predict prices of three houses
house1= sales[sales['id']==7129300520]
house1
# Out:
# Columns:
# 	id	int
# 	date	str
# 	price	int
# 	bedrooms	int
# 	bathrooms	float
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	int
# 	lat	float
# 	long	float
# 	sqft_living15	int
# 	sqft_lot15	int
# 	zipcodestr	str
#
# Rows: Unknown
#
# Data:
# +------------+-----------------+--------+----------+-----------+-------------+
# |     id     |       date      | price  | bedrooms | bathrooms | sqft_living |
# +------------+-----------------+--------+----------+-----------+-------------+
# | 7129300520 | 20141013T000000 | 221900 |    3     |    1.0    |     1180    |
# +------------+-----------------+--------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# ...

# %%
print(house1['price'])
# Out:
# [221900, ... ]

# %%
#<img src='house-7129300520.jpg'>

# %%
print(sqft_model.predict(house1))
# Out:
# [286097.56032547745]

# %%
print(my_features_model.predict(house1))
# Out:
# [289023.47565175965]

# %%
#Prediction for a second house
house2= sales[sales['id']==1925069082]
house2
# Out:
# Columns:
# 	id	int
# 	date	str
# 	price	int
# 	bedrooms	int
# 	bathrooms	float
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	int
# 	lat	float
# 	long	float
# 	sqft_living15	int
# 	sqft_lot15	int
# 	zipcodestr	str
#
# Rows: Unknown
#
# Data:
# +------------+-----------------+---------+----------+-----------+-------------+
# |     id     |       date      |  price  | bedrooms | bathrooms | sqft_living |
# +------------+-----------------+---------+----------+-----------+-------------+
# | 1925069082 | 20150511T000000 | 2200000 |    5     |    4.25   |     4640    |
# +------------+-----------------+---------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# ...

# %%
house2['price']
# Out:
# dtype: int
# Rows: ?
# [2200000, ... ]

# %%
print(sqft_model.predict(house2))
# Out:
# [1260528.3126823697]

# %%
print(my_features_model.predict(house2))
# Out:
# [1261515.249038078]

# %% [markdown]
# Assignment 2

# %% [markdown]
# 1. Selection and summary statistics:  In the notebook we covered in the module, we discovered which neighborhood (zip code) of Seattle had the highest average house sale price.  Now, take the sales data, select only the houses with this zip code, and compute the average price.

# %%
high_avg=sales[sales['zipcode']==98039]

# %%
high_avg
# Out:
# Columns:
# 	id	int
# 	date	str
# 	price	int
# 	bedrooms	int
# 	bathrooms	float
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	int
# 	lat	float
# 	long	float
# 	sqft_living15	int
# 	sqft_lot15	int
# 	zipcodestr	str
#
# Rows: Unknown
#
# Data:
# +------------+-----------------+---------+----------+-----------+-------------+
# |     id     |       date      |  price  | bedrooms | bathrooms | sqft_living |
# +------------+-----------------+---------+----------+-----------+-------------+
# | 3625049014 | 20140829T000000 | 2950000 |    4     |    3.5    |     4860    |
# | 2540700110 | 20150212T000000 | 1905000 |    4     |    3.5    |     4210    |
# | 3262300940 | 20141107T000000 |  875000 |    3     |    1.0    |     1220    |
# | 3262300940 | 20150210T000000 |  940000 |    3     |    1.0    |     1220    |
# ...

# %%
high_avg['price'].mean()
# Out:
# 2160606.6000000006

# %% [markdown]
# 2.  Filtering data: One of the key features we used in our model was the number of square feet of living space (‘sqft_living’) in the house. For this part, we are going to use the idea of filtering (selecting) data.
#
# In particular, we are going to use logical filters to select rows of an SFrame. You can find more info in the Logical Filter section of this documentation.
# Using such filters, first select the houses that have ‘sqft_living’ higher than 2000 sqft but no larger than 4000 sqft.
# What fraction of the all houses have ‘sqft_living’ in this range?

# %%
sqft_range= sales[(sales['sqft_living']<=4000) & (sales['sqft_living']>2000)]

# %%
sqft_range
# Out:
# Columns:
# 	id	int
# 	date	str
# 	price	int
# 	bedrooms	int
# 	bathrooms	float
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	int
# 	lat	float
# 	long	float
# 	sqft_living15	int
# 	sqft_lot15	int
# 	zipcodestr	str
#
# Rows: Unknown
#
# Data:
# +------------+-----------------+---------+----------+-----------+-------------+
# |     id     |       date      |  price  | bedrooms | bathrooms | sqft_living |
# +------------+-----------------+---------+----------+-----------+-------------+
# | 6414100192 | 20141209T000000 |  538000 |    3     |    2.25   |     2570    |
# | 1736800520 | 20150403T000000 |  662500 |    3     |    2.5    |     3560    |
# | 9297300055 | 20150124T000000 |  650000 |    4     |    3.0    |     2950    |
# | 2524049179 | 20140826T000000 | 2000000 |    3     |    2.75   |     3050    |
# ...

# %%
len(sqft_range)/len(sales['sqft_living'])
# Out:
# 0.42187572294452413

# %% [markdown]
# 3. Building a regression model with several more features:  In the sample notebook, we built two regression models to predict house prices, one using just ‘sqft_living’ and the other one using a few more features, we called this set my_features
# Now, going back to the original dataset, you will build a model using the following features:

# %%
advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house				
'grade', # measure of quality of construction				
'waterfront', # waterfront property				
'view', # type of view				
'sqft_above', # square feet above ground				
'sqft_basement', # square feet in basement				
'yr_built', # the year built				
'yr_renovated', # the year renovated				
'lat', 'long', # the lat-long of the parcel				
'sqft_living15', # average sq.ft. of 15 nearest neighbors 				
'sqft_lot15', # average lot size of 15 nearest neighbors 
]

# %%
#Build regression model with advanced feature
my_advanced_model= turicreate.linear_regression.create(train_data, target='price', features=advanced_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 18
# Number of unpacked features : 18
# Number of coefficients    : 19
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %%
print(sqft_model.evaluate(test_data))
print(my_features_model.evaluate(test_data))
print(my_advanced_model.evaluate(test_data))
# Out:
# {'max_error': 4145927.9156778366, 'rmse': 255180.73631157092}
# {'max_error': 3977309.726098202, 'rmse': 252862.10208038008}
# {'max_error': 4088351.130339157, 'rmse': 200045.15434437143}
